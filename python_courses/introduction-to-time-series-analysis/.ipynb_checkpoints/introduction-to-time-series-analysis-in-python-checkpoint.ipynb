# %% [markdown]
# # Introduction to time series analysis in Python

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %% [markdown]
# ## 1. Correlation and Autocorrelation

# %%
diet = pd.read_csv("data_added/diet.csv", skiprows=1, parse_dates=True, index_col="Month")
diet.columns = ["interest"]
diet.head()
# Out:
#             interest
# Month
# 2004-01-01       100
# 2004-02-01        74
# 2004-03-01        71
# 2004-04-01        69
# 2004-05-01        75

# %% [markdown]
# ### A "Thin" Application of Time Series

# %%
# Convert the date index to datetime
diet.index = pd.to_datetime(diet.index)

# Plot 2012 data using slicing
diet["2012"].plot()
plt.show()

# Plot the entire time series diet and show gridlines
diet.plot()
plt.show()

# %% [markdown]
# ### Merging Time Series With Different Dates

# %%
# %run "data_added/bonds.py"
# %run "data_added/bonds_dates.py"
# %run "data_added/stocks.py"
# %run "data_added/stocks_dates.py"

display(len(bonds))
display(len(bonds_dates))

list_keys = ["observation_date", "US10Y"]
list_values = [bonds_dates, list(bonds)]
zipped = list(zip(list_keys, list_values))
bonds = pd.DataFrame(dict(zipped))
bonds.set_index("observation_date", inplace=True)

display(bonds.head())

display(len(stocks))
display(len(stocks_dates))

list_keys = ["observation_date", "SP500"]
list_values = [stocks_dates, list(stocks)]
zipped = list(zip(list_keys, list_values))
stocks = pd.DataFrame(dict(zipped))
stocks.set_index("observation_date", inplace=True)

display(stocks.head())

#stocks = pd.DataFrame(stocks)
#stocks_dates = pd.to_datetime(stocks_dates)
#stocks = stocks.set_index(stocks_dates)
#display(stocks.head())

#SP500 = pd.DataFrame([float(x) for x in SP500.split(",")])
#US10Y = [float(x) for x in US10Y.split(",")]

#display(len(SP500))
#display(len(US10Y))

#list_keys = ["Date", "SP500", "US10Y"]
#list_values = [date_list, SP500, US10Y]
#zipped = list(zip(list_keys, list_values))
#df = pd.DataFrame(dict(zipped))
#df
# Out:
# 2503
# 2503
#                   US10Y
# observation_date
# 2007-06-08         5.12
# 2007-06-11         5.14
# 2007-06-12         5.26
# 2007-06-13         5.20
# 2007-06-14         5.23
# 2519
# 2519
#                     SP500
# observation_date
# 2007-06-11        1509.12
# 2007-06-12        1493.00
# 2007-06-13        1515.67
# 2007-06-14        1522.97
# 2007-06-15        1532.91

# %%
#stocks = pd.read_csv("data_added/SP500.csv", parse_dates=True, index_col="DATE", na_values=".")
#display(stocks.head(15))
#bonds = pd.read_csv("data_added/DGS10.csv", parse_dates=True, index_col="DATE", na_values=".")
#display(bonds.head())

# %%
# Convert the stock index and bond index into sets
set_stock_dates = set(stocks.index)
set_bond_dates = set(bonds.index)

# Take the difference between the sets and print
print(set_stock_dates - set_bond_dates)

# Merge stocks and bonds DataFrames using join()
stocks_and_bonds = stocks.join(bonds, how="inner")
# Out:
# {'2016-10-10', '2009-11-11', '2016-11-11', '2007-10-08', '2017-06-09', '2007-11-12', '2012-10-08', '2014-10-13', '2015-11-11', '2013-10-14', '2009-10-12', '2008-10-13', '2015-10-12', '2010-11-11', '2008-11-11', '2012-11-12', '2011-10-10', '2014-11-11', '2010-10-11', '2013-11-11', '2011-11-11'}

# %% [markdown]
# ### Correlation of Stocks and Bonds

# %%
display(stocks_and_bonds.loc[:,["SP500"]].head())
display(stocks_and_bonds.loc[:,["US10Y"]].head())
# Out:
#                     SP500
# observation_date
# 2007-06-11        1509.12
# 2007-06-12        1493.00
# 2007-06-13        1515.67
# 2007-06-14        1522.97
# 2007-06-15        1532.91
#                   US10Y
# observation_date
# 2007-06-11         5.14
# 2007-06-12         5.26
# 2007-06-13         5.20
# 2007-06-14         5.23
# 2007-06-15         5.16

# %%
stocks_and_bonds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1305 entries, 2014-01-02 to 2019-01-02
# Data columns (total 2 columns):
# SP500    1305 non-null object
# DGS10    1305 non-null object
# dtypes: object(2)
# memory usage: 70.6+ KB

# %%
# Compute percent change using pct_change()
returns = stocks_and_bonds.pct_change()

# Compute correlation using corr()
#correlation = returns["SP500"].corr(returns["US10Y"])
correlation = returns["SP500"].corr(returns["US10Y"])
print("Correlation of stocks and interest rates: ", correlation)

# Make scatter plot
#plt.scatter(returns["SP500"], returns["US10Y"])
plt.scatter(returns["SP500"], returns["US10Y"])
plt.show()
# Out:
# Correlation of stocks and interest rates:  0.4119448886249271

# %% [markdown]
# ### Flying Saucers Aren't Correlated to Flying Markets

# %%
dat_dji = pd.read_csv("data/data/DJI.csv", parse_dates=True, index_col="Date", na_values=".")
display(dat_dji.head())
dat_ufo = pd.read_csv("data/UFO.csv", parse_dates=True, index_col="Date", na_values=".")
display(dat_ufo.head())
levels = dat_dji.merge(dat_ufo, how="inner",left_index=True, right_index=True)
levels.columns = ["DJI", "UFO"]
display(levels.head())
# Out:
#              Value
# Date
# 1941-01-01  110.96
# 1942-01-01  119.40
# 1943-01-01  135.89
# 1944-01-01  152.32
# 1945-01-01  192.91
#             Value
# Date
# 1941-01-01      1
# 1942-01-01      2
# 1943-01-01      9
# 1944-01-01      9
# 1945-01-01      9
#                DJI  UFO
# Date
# 1941-01-01  110.96    1
# 1942-01-01  119.40    2
# 1943-01-01  135.89    9
# 1944-01-01  152.32    9
# 1945-01-01  192.91    9

# %%
levels.plot()
plt.show()

# %%
# Compute correlation of levels
correlation1 = levels["DJI"].corr(levels["UFO"])
print("Correlation of levels: ", correlation1)

# Compute correlation of percent changes
changes = levels.pct_change()
correlation2 = changes["DJI"].corr(changes["UFO"])
print("Correlation of changes: ", correlation2)
# Out:
# Correlation of levels:  0.9399762210726428
# Correlation of changes:  0.06026935462405373

# %% [markdown]
# ### Looking at a Regression's R-Squared

# %%
# %run "data_added/x.py"
# %run "data_added/y.py"

x = pd.Series(x)
y = pd.Series(y)

# %%
# Import the statsmodels module
import statsmodels.api as sm

# Compute correlation of x and y
correlation = x.corr(y)
print("The correlation between x and y is %4.2f" %(correlation))

# Convert the Series x to a DataFrame and name the column x
x = pd.DataFrame(x, columns=['x'])

# Add a constant to the DataFrame x
x = sm.add_constant(x)

# Fit the regression of y on x
result = sm.OLS(y, x).fit()

# Print out the results and look at the relationship between R-squared and the correlation above
print(result.summary())
# Out:
# The correlation between x and y is -0.90
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.816
# Model:                            OLS   Adj. R-squared:                  0.815
# Method:                 Least Squares   F-statistic:                     4414.
# Date:                Sat, 05 Jan 2019   Prob (F-statistic):               0.00
# Time:                        22:02:58   Log-Likelihood:                -588.19
# No. Observations:                1000   AIC:                             1180.
# Df Residuals:                     998   BIC:                             1190.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0040      0.014      0.289      0.772      -0.023       0.031
# ...

# %% [markdown]
# ### A Popular Strategy Using Autocorrelation

# %% [markdown]
# ### Are Interest Rates Autocorrelated?

# %% [markdown]
# ## 2. Some simple time series

# %% [markdown]
# ### Taxing Exercise: Compute the ACF

# %% [markdown]
# ### Are We Confident This Stock is Mean Reverting?

# %% [markdown]
# ### Can't Forecast White Noise

# %% [markdown]
# ### Generate a Random Walk

# %% [markdown]
# ### Get the Drift

# %% [markdown]
# ### Are Stock Prices a Random Walk?

# %% [markdown]
# ### How About Stock Returns?

# %% [markdown]
# ### Seasonal Adjustment During Tax Season

# %% [markdown]
# ## 3. Autoregressive (AR) models

# %% [markdown]
# ### Simulate AR(1) Time Series

# %% [markdown]
# ### Compare the ACF for Several AR Time Series

# %% [markdown]
# ### Estimating an AR Model

# %% [markdown]
# ### Forecasting with an AR Model

# %% [markdown]
# ### Let's Forecast Interest Rates

# %% [markdown]
# ### Compare AR Model with Random Walk

# %% [markdown]
# ### Estimate Order of Model: PACF

# %% [markdown]
# ### Estimate Order of Model: PACF

# %% [markdown]
# ### Estimate Order of Model: Information Criteria

# %% [markdown]
# ## 4. Moving average (MA) and ARMA models

# %% [markdown]
# ### Simulate MA(1) Time Series

# %% [markdown]
# ### Compute the ACF for Several MA Time Series

# %% [markdown]
# ### Estimating an MA Model

# %% [markdown]
# ### Forecasting with MA Model

# %% [markdown]
# ### High Frequency Stock Prices

# %% [markdown]
# ### High Frequency Stock Prices

# %% [markdown]
# ### Applying an MA Model

# %% [markdown]
# ### Equivalence of AR(1) and MA(infinity)

# %% [markdown]
# ## 5. Putting it all together

# %% [markdown]
# ### A Dog on a Leash? (Part 1)

# %% [markdown]
# ### A Dog on a Leash? (Part 2)

# %% [markdown]
# ### Are Bitcoin and Ethereum Cointegrated?

# %% [markdown]
# ### Is Temperature a Random Walk (with Drift)?

# %% [markdown]
# ### Getting "Warmed" Up: Look at Autocorrelations

# %% [markdown]
# ### Which ARMA Model is Best?

# %% [markdown]
# ### Don't Throw Out That Winter Coat Yet
